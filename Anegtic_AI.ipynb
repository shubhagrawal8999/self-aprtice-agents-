# %% [markdown]
# <a href="https://colab.research.google.com/github/shubhagrawal8999/self-aprtice-agents-/blob/main/Anegtic_AI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DAY two of agentic ai !!!**

# %%
import os
import json
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override = True)
# Out:
# False

# %%
openai_api_key = ""

if openai_api_key:
  print(f"OpenAI key exist and begin with {openai_api_key[:8]}")

else:
  print("error")
# Out:
# OpenAI key exist and begin with sk-proj-

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
requests = "Please come up with a challange ,naunched question that i ask a numberof LLms to evalute their intelligence."
requests += "Answer only with the question , no explanation"
message =[{"role":"user","content":requests}]

# %%
message
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challange ,naunched question that i ask a numberof LLms to evalute their intelligence.Answer only with the question , no explanation'}]

# %%
openai = OpenAI(api_key=openai_api_key)
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages = message,
)
question = response.choices[0].message.content
print(question)
# Out:
# Design a self-contained cross-domain puzzle that requires logic, mathematics, and linguistic insight, has a unique solution, and is solvable without external data or tools. Present the puzzle clearly and specify the required deliverable: the final answer, a concise justification, and a brief outline of an alternative solution path that yields the same conclusion.

# %%
compitors = []
answers =[]
messages = [{"role":"user","content":question}]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1957123027.py in <cell line: 0>()
#       1 compitors = []
#       2 answers =[]
# ----> 3 messages = [{"role":"user","content":question}]
#
# NameError: name 'question' is not defined

# %%
from IPython.display import Markdown
openai = OpenAI(api_key=openai_api_key)
model = "gpt-5-nano"
response = openai.chat.completions.create(model=model,messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
compitors.append(answer)
# Out:
# Puzzle: The Four-Letter Word Challenge
#
# Goal: Find a four-letter English word W = w1 w2 w3 w4 that satisfies all clues below. You will use logic, a bit of math (alphabetical positions), and a touch of linguistic intuition (common letter combinations) to deduce the unique word.
#
# Clues
# 1) The first letter is the 13th letter of the alphabet.
# 2) The middle two letters form a common English digraph: AT.
# 3) The last letter is the 8th letter of the alphabet.
# 4) The sum of the alphabetical positions (A=1, B=2, ..., Z=26) of the four letters equals 42.
#
# Deliverables
# - Final answer: The four-letter word W.
# - Concise justification: A short, clear rationale showing how the clues lead to the answer.
# - Brief outline of an alternative solution path that yields the same conclusion: a second, distinct but equivalent reasoning route to the same final word.
#
# Solution
#
# Final answer
# MATH
#
# Concise justification (how the clues lead to MATH)
# ...

# %%
from IPython.display import Markdown

gemini = OpenAI(api_key = "",base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model,messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
compitors.append(model)
# Out:
# Here is the self-contained, cross-domain puzzle:
#
# ## The Tripartite Cipher
#
# To unlock the final answer, you must discover a three-letter word. Each letter is derived from a distinct intellectual domain: Linguistics, Mathematics, and Logic. All necessary information is contained within this puzzle. No external resources or tools (like dictionaries, calculators, or internet searches) are required.
#
# ---
#
# ### Part 1: The First Letter (Linguistic Insight)
#
# Consider the following riddle:
# "I have cities, but no houses; forests, but no trees; and water, but no fish. What am I?"
#
# Once you have identified the answer, take its *fourth* letter. The letter corresponding to this numerical position in the English alphabet (A=1, B=2, ..., Z=26) will be the first letter of our three-letter word.
#
# ---
#
# ### Part 2: The Second Letter (Mathematical Calculation)
#
# Observe the following sequence of numbers:
# 1, 2, 4, 7, 11, X
#
# ...

# %%
compitor =[]
answer= []

# %%
answer = """Puzzle: The Four-Letter Word Challenge

Goal: Find a four-letter English word W = w1 w2 w3 w4 that satisfies all clues below. You will use logic, a bit of math (alphabetical positions), and a touch of linguistic intuition (common letter combinations) to deduce the unique word.

Clues

The first letter is the 13th letter of the alphabet.
The middle two letters form a common English digraph: AT.
The last letter is the 8th letter of the alphabet.
The sum of the alphabetical positions (A=1, B=2, ..., Z=26) of the four letters equals 42.
Deliverables

Final answer: The four-letter word W.
Concise justification: A short, clear rationale showing how the clues lead to the answer.
Brief outline of an alternative solution path that yields the same conclusion: a second, distinct but equivalent reasoning route to the same final word.
Solution

Final answer MATH

Concise justification (how the clues lead to MATH)

Clue 1: The first letter is the 13th letter. The 13th letter is M. So w1 = M.
Clue 2: The middle two letters form the digraph AT. So w2 = A and w3 = T.
Clue 3: The last letter is the 8th letter. The 8th letter is H. So w4 = H.
Clue 4: Check the alphabet positions: M(13) + A(1) + T(20) + H(8) = 42, which matches the required sum.
Since all four clues lock in exactly M, A, T, H, the only word that fits is MATH. The combination of logic (where clues pin down the structure), mathematics (the letter-sum check), and linguistic insight (recognizing the common digraph AT) yields a unique solution.

Alternative solution path (outline)

Route A (direct): Use Clues 1, 2, and 3 to fix w1 = M, w2 = A, w3 = T, w4 = H immediately. Then verify with Clue 4, which indeed gives 42. This confirms MATH.
Route B (sum-first with a cross-check): From Clue 4, the total must be 42. Knowing w1 is M (13) and w4 is H (8) from Clues 1 and 3, we get w2 + w3 = 42 − 13 − 8 = 21. The middle two letters must form a common digraph of a two-letter sum equal to 21; the only such common digraph among English digraphs that also matches the other constraints is AT (A=1, T=20; sum 21). Therefore w2 = A, w3 = T, leading again to MATH. This route arrives at the same conclusion via a different focal point.
Notes

The puzzle is self-contained: all data (alphabet positions and the digraph AT) are defined within the puzzle, with no need for external sources.
The final answer is uniquely determined by the four clues."""

# %%
answer_2 = """The Tripartite Cipher
To unlock the final answer, you must discover a three-letter word. Each letter is derived from a distinct intellectual domain: Linguistics, Mathematics, and Logic. All necessary information is contained within this puzzle. No external resources or tools (like dictionaries, calculators, or internet searches) are required.

Part 1: The First Letter (Linguistic Insight)
Consider the following riddle: "I have cities, but no houses; forests, but no trees; and water, but no fish. What am I?"

Once you have identified the answer, take its fourth letter. The letter corresponding to this numerical position in the English alphabet (A=1, B=2, ..., Z=26) will be the first letter of our three-letter word.

Part 2: The Second Letter (Mathematical Calculation)
Observe the following sequence of numbers: 1, 2, 4, 7, 11, X

Determine the value of X. This value, when converted to its corresponding letter in the English alphabet (A=1, B=2, ..., Z=26), will be the second letter of our three-letter word.

Part 3: The Third Letter (Logical Deduction)
Four distinct letters (R, S, T, U) are arranged in a line, each occupying a unique position from left to right. Deduce their exact order based on these clues:

S is immediately to the right of R.
T is not at either end of the arrangement.
U is somewhere to the left of S.
The letter found in the second position of this arrangement will be the third letter of our three-letter word.

Required Deliverables:
The final three-letter word.
A concise justification for each step (for Part 1, 2, and 3) leading to the individual letters.
A brief outline of an alternative solution path that yields the same conclusion for at least two of the puzzle's parts.
Solution
1. The Final Three-Letter Word:
PPT

2. Concise Justification:
Part 1: Linguistic Insight (First Letter)

The riddle "I have cities, but no houses; forests, but no trees; and water, but no fish. What am I?" describes a MAP.
The fourth letter of "MAP" is P.
P is the 16th letter of the alphabet. Therefore, the first letter of the solution is P.
Part 2: Mathematical Calculation (Second Letter)

The sequence is 1, 2, 4, 7, 11, X.
By finding the differences between successive terms:
2 - 1 = 1
4 - 2 = 2
7 - 4 = 3
11 - 7 = 4
The differences form an arithmetic progression (1, 2, 3, 4). The next difference must be 5.
Therefore, X = 11 + 5 = 16.
The 16th letter of the alphabet is P. Therefore, the second letter of the solution is P.
Part 3: Logical Deduction (Third Letter)

Let the four positions be denoted by _ _ _ _.
From Clue 1: S is immediately to the right of R. This means we have a fixed block "RS". Possible arrangements: RS _ _, _ RS _, _ _ RS.
From Clue 3: U is somewhere to the left of S. Since S is part of the "RS" block, U must be to the left of the entire "RS" block.
If RS _ _, then U must be before R, i.e., U RS _. The last position must be T. So URST.
If _ RS _, then U must be before R, i.e., U RS _. The last position must be T. So URST. (Same as above)
If _ _ RS, then U must be in the first or second position.
If U is first: U _ RS. The second position must be T. So UTRS.
If U is second: _ U RS. This is not possible because R must be immediately left of S, so R would have to be in the first position, leaving no room for U before RS.
So, the only two candidate arrangements are URST and UTRS.
From Clue 2: T is not at either end of the arrangement.
In URST, T is at the last position (an end). This arrangement is invalid.
In UTRS, T is in the second position (not an end). This arrangement is valid.
Therefore, the correct arrangement is UTRS.
The letter in the second position is T. Therefore, the third letter of the solution is T.
3. Brief Outline of Alternative Solution Paths:
While the overall puzzle structure dictates which domain solves for which letter, alternative approaches can be used within individual parts:

Part 2: Mathematical Calculation (Second Letter)

Original Path: Identifying the pattern in successive differences (1, 2, 3, 4, then 5).
Alternative Path: Deriving a general formula for the sequence. The sequence is defined by $a_n = a_{n-1} + (n-1)$, where $a_1=1$.
$a_1 = 1$
$a_2 = a_1 + 1 = 2$
$a_3 = a_2 + 2 = 4$
$a_4 = a_3 + 3 = 7$
$a_5 = a_4 + 4 = 11$
$a_6 = a_5 + 5 = 16$. This formula confirms X=16.
Part 3: Logical Deduction (Third Letter)

Original Path: Step-by-step deduction by combining clues and eliminating possibilities for the arrangement.
Alternative Path: Systematically listing all permutations that satisfy Clue 1, then filtering those using Clue 3, and finally using Clue 2.
List all permutations of R, S, T, U. (4! = 24 permutations)
Filter for "S immediately to the right of R" (i.e., "RS" block). This leaves 6 permutations:
RSTU, RUTS
TRSU, URST
TURS, UTRS
Filter for "U is somewhere to the left of S".
RSTU (U is right of S) - OUT
RUTS (U is right of S) - OUT
TRSU (U is right of S) - OUT
URST (U is left of S) - IN
TURS (U is right of S) - OUT
UTRS (U is left of S) - IN This leaves URST and UTRS.
Filter for "T is not at either end".
URST (T is at the end) - OUT
UTRS (T is in the second position) - IN This systematic elimination yields UTRS as the unique solution. """

# %%
compitor = []

# %%
compitor.append("gpt-5-nano")
compitor.append(answer)
compitor.append("gemini-2.5-flash")
compitor.append(answer_2)

# %%
print(compitor)
# Out:
# ['gpt-5-nano', [], 'gemini-2.5-flash', 'gpt-5-nano', 'Puzzle: The Four-Letter Word Challenge\n\nGoal: Find a four-letter English word W = w1 w2 w3 w4 that satisfies all clues below. You will use logic, a bit of math (alphabetical positions), and a touch of linguistic intuition (common letter combinations) to deduce the unique word.\n\nClues\n\nThe first letter is the 13th letter of the alphabet.\nThe middle two letters form a common English digraph: AT.\nThe last letter is the 8th letter of the alphabet.\nThe sum of the alphabetical positions (A=1, B=2, ..., Z=26) of the four letters equals 42.\nDeliverables\n\nFinal answer: The four-letter word W.\nConcise justification: A short, clear rationale showing how the clues lead to the answer.\nBrief outline of an alternative solution path that yields the same conclusion: a second, distinct but equivalent reasoning route to the same final word.\nSolution\n\nFinal answer MATH\n\nConcise justification (how the clues lead to MATH)\n\nClue 1: 
# ...
